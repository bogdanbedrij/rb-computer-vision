# %% [markdown]
# # HOMEWORK 14
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,213,002
# Trainable params: 3,213,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 [==============================] - 97s 102ms/step - loss: 0.3855 - accuracy: 0.8635 - val_loss: 0.3237 - val_accuracy: 0.8838
# Epoch 2/50
# 938/938 [==============================] - 84s 89ms/step - loss: 0.2649 - accuracy: 0.9047 - val_loss: 0.2954 - val_accuracy: 0.8937
# Epoch 3/50
# 938/938 [==============================] - 81s 86ms/step - loss: 0.2260 - accuracy: 0.9179 - val_loss: 0.3053 - val_accuracy: 0.8956
# Epoch 4/50
# 938/938 [==============================] - 83s 88ms/step - loss: 0.1962 - accuracy: 0.9276 - val_loss: 0.2948 - val_accuracy: 0.8998
# Epoch 5/50
# 938/938 [==============================] - 83s 88ms/step - loss: 0.1736 - accuracy: 0.9365 - val_loss: 0.3122 - val_accuracy: 0.8993
# Epoch 6/50
# 938/938 [==============================] - 82s 87ms/step - loss: 0.1558 - accuracy: 0.9429 - val_loss: 0.3068 - val_accuracy: 0.9036
# Epoch 7/50
# 938/938 [==============================] - 79s 84ms/step - loss: 0.1390 - accuracy: 0.9488 - val_loss: 0.3324 - val_accuracy: 0.9006
# Epoch 8/50
# 938/938 [==============================] - 75s 80ms/step - loss: 0.1260 - accuracy: 0.9542 - val_loss: 0.3602 - val_accuracy: 0.8952
# Epoch 9/50
# 938/938 [==============================] - 75s 80ms/step - loss: 0.1131 - accuracy: 0.9588 - val_loss: 0.3965 - val_accuracy: 0.8961
# Epoch 10/50
# 938/938 [==============================] - 75s 80ms/step - loss: 0.1036 - accuracy: 0.9625 - val_loss: 0.4147 - val_accuracy: 0.8906
# Epoch 11/50
# 938/938 [==============================] - 76s 81ms/step - loss: 0.0927 - accuracy: 0.9663 - val_loss: 0.4260 - val_accuracy: 0.8960
# Epoch 12/50
# 938/938 [==============================] - 76s 81ms/step - loss: 0.0843 - accuracy: 0.9700 - val_loss: 0.4489 - val_accuracy: 0.8932
# Epoch 13/50
# 938/938 [==============================] - 76s 81ms/step - loss: 0.0772 - accuracy: 0.9725 - val_loss: 0.4798 - val_accuracy: 0.8924
# Epoch 14/50
# 938/938 [==============================] - 77s 82ms/step - loss: 0.0692 - accuracy: 0.9740 - val_loss: 0.4804 - val_accuracy: 0.8969
# Epoch 15/50
# 938/938 [==============================] - 76s 81ms/step - loss: 0.0640 - accuracy: 0.9765 - val_loss: 0.5540 - val_accuracy: 0.8869
# Epoch 16/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0582 - accuracy: 0.9792 - val_loss: 0.5871 - val_accuracy: 0.8902
# Epoch 17/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0545 - accuracy: 0.9803 - val_loss: 0.5997 - val_accuracy: 0.8876
# Epoch 18/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0514 - accuracy: 0.9813 - val_loss: 0.6186 - val_accuracy: 0.8915
# Epoch 19/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0458 - accuracy: 0.9828 - val_loss: 0.6732 - val_accuracy: 0.8919
# Epoch 20/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0454 - accuracy: 0.9843 - val_loss: 0.6710 - val_accuracy: 0.8909
# Epoch 21/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0405 - accuracy: 0.9850 - val_loss: 0.7112 - val_accuracy: 0.8921
# Epoch 22/50
# 938/938 [==============================] - 72s 77ms/step - loss: 0.0401 - accuracy: 0.9853 - val_loss: 0.6943 - val_accuracy: 0.8952
# Epoch 23/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0358 - accuracy: 0.9872 - val_loss: 0.8005 - val_accuracy: 0.8818
# Epoch 24/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0369 - accuracy: 0.9866 - val_loss: 0.7652 - val_accuracy: 0.8864
# Epoch 25/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0321 - accuracy: 0.9885 - val_loss: 0.8125 - val_accuracy: 0.8839
# Epoch 26/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0315 - accuracy: 0.9885 - val_loss: 0.8441 - val_accuracy: 0.8865
# Epoch 27/50
# 938/938 [==============================] - 75s 80ms/step - loss: 0.0331 - accuracy: 0.9883 - val_loss: 0.8531 - val_accuracy: 0.8849
# Epoch 28/50
# 938/938 [==============================] - 72s 76ms/step - loss: 0.0293 - accuracy: 0.9898 - val_loss: 0.8984 - val_accuracy: 0.8871
# Epoch 29/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0280 - accuracy: 0.9901 - val_loss: 0.8746 - val_accuracy: 0.8872
# Epoch 30/50
# 938/938 [==============================] - 75s 80ms/step - loss: 0.0256 - accuracy: 0.9915 - val_loss: 0.9256 - val_accuracy: 0.8886
# Epoch 31/50
# 938/938 [==============================] - 71s 76ms/step - loss: 0.0287 - accuracy: 0.9898 - val_loss: 0.9264 - val_accuracy: 0.8812
# Epoch 32/50
# 938/938 [==============================] - 72s 77ms/step - loss: 0.0204 - accuracy: 0.9926 - val_loss: 0.9576 - val_accuracy: 0.8874
# Epoch 33/50
# 938/938 [==============================] - 72s 77ms/step - loss: 0.0308 - accuracy: 0.9896 - val_loss: 0.9670 - val_accuracy: 0.8843
# Epoch 34/50
# 938/938 [==============================] - 73s 77ms/step - loss: 0.0239 - accuracy: 0.9915 - val_loss: 1.0263 - val_accuracy: 0.8812
# Epoch 35/50
# 938/938 [==============================] - 72s 77ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 1.0501 - val_accuracy: 0.8845
# Epoch 36/50
# 938/938 [==============================] - 72s 77ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 1.0242 - val_accuracy: 0.8802
# Epoch 37/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0247 - accuracy: 0.9917 - val_loss: 1.0048 - val_accuracy: 0.8834
# Epoch 38/50
# 938/938 [==============================] - 71s 76ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 1.1375 - val_accuracy: 0.8828
# Epoch 39/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0190 - accuracy: 0.9934 - val_loss: 1.0802 - val_accuracy: 0.8899
# Epoch 40/50
# 938/938 [==============================] - 75s 80ms/step - loss: 0.0181 - accuracy: 0.9934 - val_loss: 1.1460 - val_accuracy: 0.8842
# Epoch 41/50
# 938/938 [==============================] - 72s 77ms/step - loss: 0.0198 - accuracy: 0.9929 - val_loss: 1.1291 - val_accuracy: 0.8888
# Epoch 42/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0197 - accuracy: 0.9929 - val_loss: 1.1415 - val_accuracy: 0.8861
# Epoch 43/50
# 938/938 [==============================] - 75s 80ms/step - loss: 0.0177 - accuracy: 0.9942 - val_loss: 1.1815 - val_accuracy: 0.8882
# Epoch 44/50
# 938/938 [==============================] - 72s 77ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 1.2405 - val_accuracy: 0.8792
# Epoch 45/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0212 - accuracy: 0.9930 - val_loss: 1.1991 - val_accuracy: 0.8867
# Epoch 46/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 1.1918 - val_accuracy: 0.8858
# Epoch 47/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 1.1806 - val_accuracy: 0.8904
# Epoch 48/50
# 938/938 [==============================] - 75s 80ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 1.1914 - val_accuracy: 0.8872
# Epoch 49/50
# 938/938 [==============================] - 74s 79ms/step - loss: 0.0169 - accuracy: 0.9943 - val_loss: 1.2755 - val_accuracy: 0.8824
# Epoch 50/50
# 938/938 [==============================] - 73s 78ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 1.2771 - val_accuracy: 0.8847

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.9954666495323181
# Validation Acc 0.8847000002861023

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Dropout(0.2)(net)
net = Flatten()(net)
net = Dense(128)(net)
net = Dropout(0.5)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        320
#
#  dropout_2 (Dropout)         (None, 28, 28, 32)        0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 128)               3211392
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,213,002
# Trainable params: 3,213,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the network
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 [==============================] - 104s 109ms/step - loss: 0.4432 - accuracy: 0.8483 - val_loss: 0.3307 - val_accuracy: 0.8818
# Epoch 2/50
# 938/938 [==============================] - 100s 106ms/step - loss: 0.3095 - accuracy: 0.8905 - val_loss: 0.3008 - val_accuracy: 0.8939
# Epoch 3/50
# 938/938 [==============================] - 103s 110ms/step - loss: 0.2727 - accuracy: 0.9021 - val_loss: 0.2957 - val_accuracy: 0.8935
# Epoch 4/50
# 938/938 [==============================] - 102s 109ms/step - loss: 0.2482 - accuracy: 0.9101 - val_loss: 0.2815 - val_accuracy: 0.9013
# Epoch 5/50
# 938/938 [==============================] - 104s 110ms/step - loss: 0.2307 - accuracy: 0.9172 - val_loss: 0.2985 - val_accuracy: 0.8976
# Epoch 6/50
# 938/938 [==============================] - 99s 106ms/step - loss: 0.2154 - accuracy: 0.9218 - val_loss: 0.2843 - val_accuracy: 0.9032
# Epoch 7/50
# 938/938 [==============================] - 104s 111ms/step - loss: 0.2004 - accuracy: 0.9277 - val_loss: 0.3061 - val_accuracy: 0.8961
# Epoch 8/50
# 938/938 [==============================] - 106s 113ms/step - loss: 0.1931 - accuracy: 0.9291 - val_loss: 0.3015 - val_accuracy: 0.8999
# Epoch 9/50
# 938/938 [==============================] - 101s 108ms/step - loss: 0.1839 - accuracy: 0.9331 - val_loss: 0.3090 - val_accuracy: 0.9047
# Epoch 10/50
# 938/938 [==============================] - 101s 108ms/step - loss: 0.1748 - accuracy: 0.9358 - val_loss: 0.3110 - val_accuracy: 0.8982
# Epoch 11/50
# 938/938 [==============================] - 121s 129ms/step - loss: 0.1674 - accuracy: 0.9387 - val_loss: 0.3192 - val_accuracy: 0.9020
# Epoch 12/50
# 938/938 [==============================] - 112s 119ms/step - loss: 0.1579 - accuracy: 0.9427 - val_loss: 0.3323 - val_accuracy: 0.8998
# Epoch 13/50
# 938/938 [==============================] - 103s 110ms/step - loss: 0.1518 - accuracy: 0.9437 - val_loss: 0.3239 - val_accuracy: 0.9025
# Epoch 14/50
# 938/938 [==============================] - 103s 110ms/step - loss: 0.1459 - accuracy: 0.9463 - val_loss: 0.3274 - val_accuracy: 0.9012
# Epoch 15/50
# 938/938 [==============================] - 97s 103ms/step - loss: 0.1416 - accuracy: 0.9466 - val_loss: 0.3680 - val_accuracy: 0.8914
# Epoch 16/50
# 938/938 [==============================] - 96s 103ms/step - loss: 0.1343 - accuracy: 0.9497 - val_loss: 0.3590 - val_accuracy: 0.9027
# Epoch 17/50
# 938/938 [==============================] - 97s 103ms/step - loss: 0.1316 - accuracy: 0.9526 - val_loss: 0.3653 - val_accuracy: 0.8960
# Epoch 18/50
# 938/938 [==============================] - 96s 102ms/step - loss: 0.1281 - accuracy: 0.9523 - val_loss: 0.3650 - val_accuracy: 0.9008
# Epoch 19/50
# 938/938 [==============================] - 95s 102ms/step - loss: 0.1209 - accuracy: 0.9559 - val_loss: 0.3728 - val_accuracy: 0.9026
# Epoch 20/50
# 938/938 [==============================] - 94s 100ms/step - loss: 0.1195 - accuracy: 0.9559 - val_loss: 0.3881 - val_accuracy: 0.9011
# Epoch 21/50
# 938/938 [==============================] - 95s 101ms/step - loss: 0.1144 - accuracy: 0.9569 - val_loss: 0.4021 - val_accuracy: 0.8989
# Epoch 22/50
# 938/938 [==============================] - 95s 101ms/step - loss: 0.1155 - accuracy: 0.9577 - val_loss: 0.4237 - val_accuracy: 0.8972
# Epoch 23/50
# 938/938 [==============================] - 95s 101ms/step - loss: 0.1131 - accuracy: 0.9586 - val_loss: 0.4151 - val_accuracy: 0.8968
# Epoch 24/50
# 938/938 [==============================] - 96s 102ms/step - loss: 0.1115 - accuracy: 0.9584 - val_loss: 0.4054 - val_accuracy: 0.8966
# Epoch 25/50
# 938/938 [==============================] - 96s 102ms/step - loss: 0.1054 - accuracy: 0.9601 - val_loss: 0.4226 - val_accuracy: 0.8937
# Epoch 26/50
# 938/938 [==============================] - 94s 100ms/step - loss: 0.1041 - accuracy: 0.9613 - val_loss: 0.4154 - val_accuracy: 0.9021
# Epoch 27/50
# 938/938 [==============================] - 95s 101ms/step - loss: 0.1043 - accuracy: 0.9625 - val_loss: 0.4359 - val_accuracy: 0.9002
# Epoch 28/50
# 938/938 [==============================] - 98s 105ms/step - loss: 0.1013 - accuracy: 0.9629 - val_loss: 0.4456 - val_accuracy: 0.8976
# Epoch 29/50
# 938/938 [==============================] - 100s 106ms/step - loss: 0.0990 - accuracy: 0.9635 - val_loss: 0.4361 - val_accuracy: 0.8993
# Epoch 30/50
# 938/938 [==============================] - 99s 106ms/step - loss: 0.0983 - accuracy: 0.9640 - val_loss: 0.4453 - val_accuracy: 0.9004
# Epoch 31/50
# 938/938 [==============================] - 102s 109ms/step - loss: 0.0982 - accuracy: 0.9634 - val_loss: 0.4567 - val_accuracy: 0.8994
# Epoch 32/50
# 938/938 [==============================] - 100s 106ms/step - loss: 0.0961 - accuracy: 0.9653 - val_loss: 0.4586 - val_accuracy: 0.8977
# Epoch 33/50
# 938/938 [==============================] - 102s 109ms/step - loss: 0.0942 - accuracy: 0.9650 - val_loss: 0.4536 - val_accuracy: 0.8990
# Epoch 34/50
# 938/938 [==============================] - 96s 102ms/step - loss: 0.0933 - accuracy: 0.9655 - val_loss: 0.4620 - val_accuracy: 0.8989
# Epoch 35/50
# 938/938 [==============================] - 94s 100ms/step - loss: 0.0902 - accuracy: 0.9668 - val_loss: 0.4708 - val_accuracy: 0.9002
# Epoch 36/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.0893 - accuracy: 0.9676 - val_loss: 0.4761 - val_accuracy: 0.8990
# Epoch 37/50
# 938/938 [==============================] - 95s 101ms/step - loss: 0.0903 - accuracy: 0.9665 - val_loss: 0.4784 - val_accuracy: 0.8981
# Epoch 38/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.0881 - accuracy: 0.9675 - val_loss: 0.4900 - val_accuracy: 0.8930
# Epoch 39/50
# 938/938 [==============================] - 88s 94ms/step - loss: 0.0855 - accuracy: 0.9690 - val_loss: 0.4870 - val_accuracy: 0.8931
# Epoch 40/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.0900 - accuracy: 0.9671 - val_loss: 0.4845 - val_accuracy: 0.8954
# Epoch 41/50
# 938/938 [==============================] - 89s 95ms/step - loss: 0.0832 - accuracy: 0.9688 - val_loss: 0.5098 - val_accuracy: 0.8933
# Epoch 42/50
# 938/938 [==============================] - 89s 95ms/step - loss: 0.0831 - accuracy: 0.9693 - val_loss: 0.4898 - val_accuracy: 0.8985
# Epoch 43/50
# 938/938 [==============================] - 89s 95ms/step - loss: 0.0809 - accuracy: 0.9698 - val_loss: 0.5107 - val_accuracy: 0.8950
# Epoch 44/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.0824 - accuracy: 0.9695 - val_loss: 0.4991 - val_accuracy: 0.8923
# Epoch 45/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.0795 - accuracy: 0.9711 - val_loss: 0.5405 - val_accuracy: 0.8997
# Epoch 46/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.0801 - accuracy: 0.9712 - val_loss: 0.5247 - val_accuracy: 0.8973
# Epoch 47/50
# 938/938 [==============================] - 89s 95ms/step - loss: 0.0808 - accuracy: 0.9711 - val_loss: 0.5238 - val_accuracy: 0.8972
# Epoch 48/50
# 938/938 [==============================] - 87s 93ms/step - loss: 0.0821 - accuracy: 0.9710 - val_loss: 0.5191 - val_accuracy: 0.8964
# Epoch 49/50
# 938/938 [==============================] - 89s 95ms/step - loss: 0.0790 - accuracy: 0.9711 - val_loss: 0.5309 - val_accuracy: 0.8952
# Epoch 50/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.0784 - accuracy: 0.9704 - val_loss: 0.5517 - val_accuracy: 0.8948

# %%
# Show the results
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.9704499840736389
# Validation Acc 0.8948000073432922

# %% [markdown]
# ### Questions
#
# * What have you done in order to improve the performance?
# * Have you tried configurations that did not work out?

# %%
# Reducing the number of parameters (the size of the network)
inputs_2 = Input(shape=(28, 28, 1))
net_2 = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net_2 = Flatten()(net_2)
net_2 = Dense(32)(net_2)
outputs_2 = Dense(10, activation="softmax")(net_2)

model_2 = Model(inputs, outputs)
model_2.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        320
#
#  dropout_2 (Dropout)         (None, 28, 28, 32)        0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 128)               3211392
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,213,002
# Trainable params: 3,213,002
# Non-trainable params: 0
# _________________________________________________________________
